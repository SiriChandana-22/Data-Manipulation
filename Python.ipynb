# %%
#importing required libraries
import pandas as pd
import numpy as np

# %%
s1 = np.array([2,4,8])
s2 = np.array([10,12,15])
np.corrcoef(s1,s2)[0][1] # to find correlation
# Out:
# 0.9971764649527379

# %%
df = pd.read_csv ("C:\\Users\\sriva\\OneDrive\\Desktop\\supply_chain_data.csv")
print(df) #importing excel sheet and printing the data
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# ...

# %%
df1 = df.head(5) #printing first 5 coloumns
print (df1)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df2 = pd.DataFrame(df1)
df3 = display (df2)
print (df3) #printing data in the form of data frame
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df2['Price'].corr(df2['Order quantities'])  # finding the correlation of price and order quantities
# Out:
# 0.41750408334858585

# %%
x=df2.iloc[:3].values #command to print rows
print(x) #printing rows
display(x) #printing rows in the form of array
# Out:
# [['haircare' 'SKU0' 69.80800554211577 55 802 8661.996792392383
#   'Non-binary' 58 7 96 4 'Carrier B' 2.956572139430807 'Supplier 3'
#   'Mumbai' 29 215 29 46.27987924050832 'Pending' 0.2264103608499251
#   'Road' 'Route B' 187.75207545920392]
#  ['skincare' 'SKU1' 14.84352327508434 95 736 7460.900065445849 'Female'
#   53 30 37 2 'Carrier A' 9.71657477143131 'Supplier 3' 'Mumbai' 23 517 30
#   33.61676895373 'Pending' 4.854068026388706 'Road' 'Route B'
#   503.0655791496692]
#  ['haircare' 'SKU2' 11.319683293090566 34 8 9577.74962586873 'Unknown' 1
#   10 88 2 'Carrier B' 8.054479261732155 'Supplier 1' 'Mumbai' 12 971 27
#   30.688019348284204 'Pending' 4.580592619199229 'Air' 'Route C'
#   141.92028177151906]]
# array([['haircare', 'SKU0', 69.80800554211577, 55, 802,
#         8661.996792392383, 'Non-binary', 58, 7, 96, 4, 'Carrier B',
#         2.956572139430807, 'Supplier 3', 'Mumbai', 29, 215, 29,
#         46.27987924050832, 'Pending', 0.2264103608499251, 'Road',
# ...

# %%
df2.describe() #statistics of data
# Out:
#            Price  Availability  Number of products sold  Revenue generated  \
# count   5.000000      5.000000                 5.000000           5.000000
# mean   32.388010     55.600000               500.000000        7230.797612
# std    30.580853     27.609781               418.477598        2671.488048
# min     4.805496     26.000000                 8.000000        2686.505152
# 25%    11.319683     34.000000                83.000000        7460.900065
# 50%    14.843523     55.000000               736.000000        7766.836426
# 75%    61.163343     68.000000               802.000000        8661.996792
# max    69.808006     95.000000               871.000000        9577.749626
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count      5.000000    5.000000          5.000000        5.000000
# mean      28.000000   12.600000         67.200000        4.400000
# std       26.495283   10.406729         24.324884        2.607681
# ...

# %%
df.info() # information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
df2.columns #coloumn headings of data
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
df[df['Product type']=='haircare'] #filtering the data for haircare
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 2      haircare   SKU2  11.319683            34                        8
# 5      haircare   SKU5   1.699976            87                      147
# 12     haircare  SKU12  71.213389            41                      336
# 18     haircare  SKU18  36.443628            23                      620
# 22     haircare  SKU22  27.679781            55                      884
# 24     haircare  SKU24   4.156308            32                      209
# 25     haircare  SKU25  39.629344            73                      142
# 26     haircare  SKU26  97.446947             9                      353
# 30     haircare  SKU30   8.022859            10                      327
# 43     haircare  SKU43  11.743272             6                      598
# 45     haircare  SKU45  33.784138             1                       24
# ...

# %%
df[df['Product type']=='skincare'] #filtering the data for skincare
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 1      skincare   SKU1  14.843523            95                      736
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# 6      skincare   SKU6   4.078333            48                       65
# 9      skincare   SKU9  64.015733            35                      980
# 10     skincare  SKU10  15.707796            11                      996
# 11     skincare  SKU11  90.635460            95                      960
# 13     skincare  SKU13  16.160393             5                      249
# 14     skincare  SKU14  99.171329            26                      562
# 15     skincare  SKU15  36.989245            94                      469
# 16     skincare  SKU16   7.547172            74                      280
# 19     skincare  SKU19  51.123870           100                      187
# ...

# %%
df[df['Product type']=='cosmetics'] #filtering the data for cosmetics
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 7     cosmetics   SKU7  42.958384            59                      426
# 8     cosmetics   SKU8  68.717597            78                      150
# 17    cosmetics  SKU17  81.462534            82                      126
# 21    cosmetics  SKU21  84.893869            60                      601
# 23    cosmetics  SKU23   4.324341            30                      391
# 27    cosmetics  SKU27  92.557361            42                      352
# 28    cosmetics  SKU28   2.397275            12                      394
# 29    cosmetics  SKU29  63.447559             3                      253
# 33    cosmetics  SKU33  64.795435            63                      616
# 35    cosmetics  SKU35  84.957787            11                      449
# 38    cosmetics  SKU38  52.075931            75                      705
# 44    cosmetics  SKU44  51.355791            34                      919
# ...

# %%
df.drop_duplicates() #printing duplicates
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# ...
